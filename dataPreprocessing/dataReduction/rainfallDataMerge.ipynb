# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df1=pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallAfghanisthan.csv')

# %%
df1
# Out:
#      Unnamed: 0  Afghanistan  Badakhshan  Badghis  Baghlan   Balkh  Bamyan  \
# 0          1901       273.94      404.13   216.51   384.21  148.66  336.46
# 1          1902       254.85      469.07   271.20   341.22  213.69  348.80
# 2          1903       308.98      527.92   273.86   473.97  258.15  424.47
# 3          1904       299.63      473.43   256.90   477.23  226.69  439.12
# 4          1905       271.32      466.85   148.60   380.00  141.48  306.18
# ..          ...          ...         ...      ...      ...     ...     ...
# 115        2016       349.48      601.40   265.24   568.43  317.57  543.76
# 116        2017       275.81      502.50   262.46   415.00  217.26  381.91
# 117        2018       253.72      407.01   238.85   402.38  218.69  390.99
# 118        2019       365.31      557.38   326.68   507.69  345.82  452.26
# 119        2020       373.95      575.66   316.81   564.52  329.05  501.99
#
# ...

# %%
df1 = df1.iloc[99: , :]

# %%
df1
# Out:
#      Unnamed: 0  Afghanistan  Badakhshan  Badghis  Baghlan   Balkh  Bamyan  \
# 99         2000       226.99      453.54   177.72   401.73  225.97  357.14
# 100        2001       219.21      392.07   229.44   316.69  202.72  313.71
# 101        2002       289.16      495.30   305.12   445.87  312.26  415.12
# 102        2003       318.72      634.35   317.98   487.70  296.70  408.82
# 103        2004       293.25      525.33   304.62   427.00  272.56  394.33
# 104        2005       348.64      598.97   278.25   497.81  270.75  430.64
# 105        2006       327.00      606.15   265.68   544.79  291.89  492.08
# 106        2007       304.30      437.14   291.71   438.03  299.87  419.09
# 107        2008       277.36      489.84   200.23   406.34  237.15  325.57
# 108        2009       363.21      617.38   313.25   583.73  379.51  501.86
# 109        2010       279.02      542.16   235.77   446.14  232.50  393.37
# ...

# %%
df1 = df1.transpose()

# %%
df1.insert(loc = 0, column = 'state', value = df1.index)

# %%
 df1.insert(loc = 0, column = 'country', value = 'afghanistan')

# %%
df1.to_csv(r"C:\Users\Satwik K\Desktop\final dataset\afghan.csv",index=False,header=False)

# %%
df1
# Out:
#                  country        state       99      100      101      102  \
# Unnamed: 0   afghanistan   Unnamed: 0  2000.00  2001.00  2002.00  2003.00
# Afghanistan  afghanistan  Afghanistan   226.99   219.21   289.16   318.72
# Badakhshan   afghanistan   Badakhshan   453.54   392.07   495.30   634.35
# Badghis      afghanistan      Badghis   177.72   229.44   305.12   317.98
# Baghlan      afghanistan      Baghlan   401.73   316.69   445.87   487.70
# Balkh        afghanistan        Balkh   225.97   202.72   312.26   296.70
# Bamyan       afghanistan       Bamyan   357.14   313.71   415.12   408.82
# Farah        afghanistan        Farah   120.57    86.66   147.60   141.57
# Faryab       afghanistan       Faryab   206.43   229.87   305.47   301.88
# Ghazni       afghanistan       Ghazni   240.30   274.63   365.81   360.06
# Ghor         afghanistan         Ghor   270.30   295.52   330.91   327.52
# Hilmand      afghanistan      Hilmand    84.96    85.54   103.81   122.90
# ...

# %%
df2=pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallBangladesh.csv')

# %%
df2 = df2.iloc[99: , :]

# %%
df2 = df2.transpose()
df2.insert(loc = 0, column = 'state', value = df2.index)
df2.insert(loc = 0, column = 'country', value = 'Bangladesh')

# %%
df3 = pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallBrazil.csv')

# %%
df3 = df3.iloc[99: , :]

# %%
df3 = df3.transpose()
df3.insert(loc = 0, column = 'state', value = df3.index)
df3.insert(loc = 0, column = 'country', value = 'Brazil')

# %%
df4 = pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallChina.csv')

# %%
df4 = df4.iloc[99: , :]

# %%
df4 = df4.transpose()
df4.insert(loc = 0, column = 'state', value = df4.index)
df4.insert(loc = 0, column = 'country', value = 'China')

# %%
df5 = pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallColombia.csv')

# %%
df5 = df5.iloc[99: , :]

# %%
df5 = df5.transpose()
df5.insert(loc = 0, column = 'state', value = df5.index)
df5.insert(loc = 0, column = 'country', value = 'Colombia')

# %%
df6 = pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallFrance.csv')

# %%
df6
# Out:
#      Unnamed: 0  France  Alsace  Aquitaine  Auvergne  Basse-Normandie  \
# 0          1901  812.84  864.18     842.65    952.04           577.74
# 1          1902  766.73  737.39     841.44    895.41           649.58
# 2          1903  799.60  757.38     811.08    845.48           828.09
# 3          1904  678.64  704.56     712.94    694.69           699.08
# 4          1905  790.02  840.87     854.90    858.40           689.00
# ..          ...     ...     ...        ...       ...              ...
# 115        2016  817.37  925.96     884.10    867.45           760.17
# 116        2017  728.20  828.26     826.27    755.35           715.45
# 117        2018  878.16  716.22    1003.32    927.57           806.67
# 118        2019  833.10  811.33     983.68    839.70           825.92
# 119        2020  808.17  704.35     977.17    814.15           827.05
#
#      Bourgogne  Bretagne  Centre  Champagne-Ardenne  ...  Cayenne  \
# ...

# %%
df6 = df6.iloc[99: , :]

# %%
df6 = df6.transpose()
df6.insert(loc = 0, column = 'state', value = df6.index)
df6.insert(loc = 0, column = 'country', value = 'France')

# %%
df7 = pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallGermany.csv')

# %%
df7 = df7.iloc[99: , :]

# %%
df7 = df7.transpose()
df7.insert(loc = 0, column = 'state', value = df7.index)
df7.insert(loc = 0, column = 'country', value = 'Germany')

# %%
df8 = pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallIndia.csv')

# %%
df8 = df8.iloc[99: , :]

# %%
df8 = df8.transpose()
df8.insert(loc = 0, column = 'state', value = df8.index)
df8.insert(loc = 0, column = 'country', value = 'India')

# %%
df9 = pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallJapan.csv')

# %%
df9 = df9.iloc[99: , :]

# %%
df9 = df9.transpose()
df9.insert(loc = 0, column = 'state', value = df9.index)
df9.insert(loc = 0, column = 'country', value = 'Japan')

# %%
df10 = pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallKenya.csv')

# %%
df10 = df10.iloc[99: , :]

# %%
df10 = df10.transpose()
df10.insert(loc = 0, column = 'state', value = df10.index)
df10.insert(loc = 0, column = 'country', value = 'Kenya')

# %%
df11 = pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallMexico.csv')

# %%
df11 = df11.iloc[99: , :]

# %%
df11 = df11.transpose()
df11.insert(loc = 0, column = 'state', value = df11.index)
df11.insert(loc = 0, column = 'country', value = 'Mexico')

# %%
df12 = pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallRussia.csv')

# %%
df12 = df12.iloc[99: , :]

# %%
df12 = df12.transpose()
df12.insert(loc = 0, column = 'state', value = df12.index)
df12.insert(loc = 0, column = 'country', value = 'Russia')

# %%
df13 = pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallTurkey.csv')

# %%
df13 = df13.iloc[99: , :]

# %%
df13 = df13.transpose()
df13.insert(loc = 0, column = 'state', value = df13.index)
df13.insert(loc = 0, column = 'country', value = 'Turkey')

# %%
df14 = pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallUSA.csv')

# %%
df14 = df14.iloc[99: , :]

# %%
df14 = df14.transpose()
df14.insert(loc = 0, column = 'state', value = df14.index)
df14.insert(loc = 0, column = 'country', value = 'USA')

# %%
df15 = pd.read_csv('C:/Users/Satwik K/Desktop/eda project/datasets/rainfall/rainfallUzbekisthan.csv')

# %%
df15 = df15.iloc[99: , :]

# %%
df15 = df15.transpose()
df15.insert(loc = 0, column = 'state', value = df15.index)
df15.insert(loc = 0, column = 'country', value = 'Uzbekisthan')

# %%
df=pd.concat([df1, df2], axis=0)

# %%
df
# Out:
#                  country        state       99      100      101      102  \
# Unnamed: 0   afghanistan   Unnamed: 0  2000.00  2001.00  2002.00  2003.00
# Afghanistan  afghanistan  Afghanistan   226.99   219.21   289.16   318.72
# Badakhshan   afghanistan   Badakhshan   453.54   392.07   495.30   634.35
# Badghis      afghanistan      Badghis   177.72   229.44   305.12   317.98
# Baghlan      afghanistan      Baghlan   401.73   316.69   445.87   487.70
# Balkh        afghanistan        Balkh   225.97   202.72   312.26   296.70
# Bamyan       afghanistan       Bamyan   357.14   313.71   415.12   408.82
# Farah        afghanistan        Farah   120.57    86.66   147.60   141.57
# Faryab       afghanistan       Faryab   206.43   229.87   305.47   301.88
# Ghazni       afghanistan       Ghazni   240.30   274.63   365.81   360.06
# Ghor         afghanistan         Ghor   270.30   295.52   330.91   327.52
# Hilmand      afghanistan      Hilmand    84.96    85.54   103.81   122.90
# ...

# %%
df=pd.concat([df, df3], axis=0)

# %%
df=pd.concat([df, df4], axis=0)

# %%
df=pd.concat([df, df5], axis=0)

# %%
df=pd.concat([df, df6], axis=0)

# %%
df=pd.concat([df, df7], axis=0)

# %%
df=pd.concat([df, df8], axis=0)

# %%
df=pd.concat([df, df9], axis=0)

# %%
df=pd.concat([df, df10], axis=0)

# %%
df=pd.concat([df, df11], axis=0)

# %%
df=pd.concat([df, df12], axis=0)

# %%
df=pd.concat([df, df13], axis=0)

# %%
df=pd.concat([df, df14], axis=0)

# %%
df=pd.concat([df, df15], axis=0)

# %%
df.to_csv(r"C:\Users\Satwik K\Desktop\final dataset\final_datset.csv",index=False,header=False)
