# %%
import numpy as np
import pandas as pd

# %%
#change path as per the local storage
df = pd.read_csv(r"Crops_AllData_Normalized.csv",encoding ="latin1",index_col=False)
df.head(100)
# Out:
#     Area Code         Area  Item Code                 Item  Element Code  \
# 0           2  Afghanistan        221  Almonds, with shell          5312
# 1           2  Afghanistan        221  Almonds, with shell          5312
# 2           2  Afghanistan        221  Almonds, with shell          5312
# 3           2  Afghanistan        221  Almonds, with shell          5312
# 4           2  Afghanistan        221  Almonds, with shell          5312
# ..        ...          ...        ...                  ...           ...
# 95          2  Afghanistan        221  Almonds, with shell          5510
# 96          2  Afghanistan        221  Almonds, with shell          5510
# 97          2  Afghanistan        221  Almonds, with shell          5510
# 98          2  Afghanistan        221  Almonds, with shell          5510
# 99          2  Afghanistan        221  Almonds, with shell          5510
#
#            Element  Year Code  Year    Unit    Value Flag
# ...

# %%
df1 =df.groupby(['Item Code','Area'])['Area Code','Item','Element Code','Element','Year Code','Year','Unit','Value','Flag'].min()
df1
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_1784\3314371786.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1 =df.groupby(['Item Code','Area'])['Area Code','Item','Element Code','Element','Year Code','Year','Unit','Value','Flag'].min()
# C:\Users\abhis\AppData\Local\Temp\ipykernel_1784\3314371786.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   df1 =df.groupby(['Item Code','Area'])['Area Code','Item','Element Code','Element','Year Code','Year','Unit','Value','Flag'].min()
#                         Area Code                       Item  Element Code  \
# Item Code Area
# 15        Afghanistan           2                      Wheat          5312
#           Africa             5100                      Wheat          5312
# ...

# %%
df1.to_csv("c.csv")

# %%
# Out:
# <ipython-input-48-9ea16c812463>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2=df.groupby(['label'])['N','P','K','temperature','humidity','ph','rainfall'].max()

# %%
df2=pd.read_csv("c.csv")
df2
# Out:
#        Item Code          Area  Area Code                       Item  \
# 0             15   Afghanistan          2                      Wheat
# 1             15        Africa       5100                      Wheat
# 2             15       Albania          3                      Wheat
# 3             15       Algeria          4                      Wheat
# 4             15      Americas       5200                      Wheat
# ...          ...           ...        ...                        ...
# 17800       1841         World       5000  Oilcrops, Cake Equivalent
# 17801       1841         Yemen        249  Oilcrops, Cake Equivalent
# 17802       1841  Yugoslav SFR        248  Oilcrops, Cake Equivalent
# 17803       1841        Zambia        251  Oilcrops, Cake Equivalent
# 17804       1841      Zimbabwe        181  Oilcrops, Cake Equivalent
#
#        Element Code         Element  Year Code  Year Unit    Value
# 0              5312  Area harvested       1961  1961   ha   7240.0
# ...

# %%
df3=df2.sort_values("Area")

# %%
df3
# Out:
#        Item Code         Area  Area Code                          Item  \
# 0             15  Afghanistan          2                         Wheat
# 16227       1731  Afghanistan          2                      Oilcrops
# 1775         116  Afghanistan          2                      Potatoes
# 11344        541  Afghanistan          2              Fruit, stone nes
# 16057       1729  Afghanistan          2               Treenuts, Total
# ...          ...          ...        ...                           ...
# 11343        536     Zimbabwe        181               Plums and sloes
# 6321         358     Zimbabwe        181  Cabbages and other brassicas
# 13176        600     Zimbabwe        181                       Papayas
# 893           56     Zimbabwe        181                         Maize
# 17804       1841     Zimbabwe        181     Oilcrops, Cake Equivalent
#
#        Element Code         Element  Year Code  Year Unit    Value
# ...
